# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %%
cities
# Out:
# ['montepuez',
#  'ushuaia',
#  'rikitea',
#  'syracuse',
#  'boa vista',
#  'mweka',
#  'hermanus',
#  'punta arenas',
#  'mataura',
#  'lata',
#  'saleaula',
#  'ugoofaaru',
#  'mucuri',
#  'cockburn town',
#  'sinnamary',
#  'ponta do sol',
#  'busselton',
#  'nove mesto na morave',
#  'nelson bay',
#  'los llanos de aridane',
#  'kieta',
#  'taolanaro',
#  'tautira',
#  'kuhdasht',
#  'abha',
#  'kathmandu',
#  'puerto ayora',
#  'sitka',
#  'karratha',
#  'hithadhoo',
#  'cape town',
#  'vaini',
#  'manggar',
#  'sept-iles',
#  'coquimbo',
#  'itoman',
#  'shenjiamen',
#  'carnarvon',
#  'wanning',
#  'bengkulu',
#  'albany',
#  'port elizabeth',
#  'kashi',
#  'te anau',
#  'new norfolk',
#  'atuona',
#  'kapaa',
#  'dikson',
#  'blythe',
#  'whitehorse',
#  'kawana waters',
#  'mattawa',
#  'kharitonovo',
#  'olimpia',
#  'paamiut',
#  'cabo san lucas',
#  'bredasdorp',
#  'jamestown',
#  'miraflores',
#  'butaritari',
#  'vardo',
#  'bethel',
#  'meulaboh',
#  'kahului',
#  'moroto',
#  'barrow',
#  'ilulissat',
#  'nikolskoye',
#  'port alfred',
#  'castro',
#  'nizhneyansk',
#  'vila velha',
#  'honiara',
#  'kalmunai',
#  'khani',
#  'buala',
#  'avarua',
#  'georgetown',
#  'narsaq',
#  'morros',
#  'hammerfest',
#  'ostrovnoy',
#  'termiz',
#  'alpena',
#  'vilyuysk',
#  'port lincoln',
#  'alta gracia',
#  'hovd',
#  'teguise',
#  'alofi',
#  'umzimvubu',
#  'bandarbeyla',
#  'kenai',
#  'lolua',
#  'nanortalik',
#  'yulara',
#  'port hardy',
#  'kaitangata',
#  'ribeira grande',
#  'aguada de cima',
#  'leningradskiy',
#  'bafoulabe',
#  'marcona',
#  'illoqqortoormiut',
#  'pevek',
#  'yellowknife',
#  'bluff',
#  'mys shmidta',
#  'pacific grove',
#  'thompson',
#  'chumphon',
#  'longyearbyen',
#  'horadiz',
#  'santa quiteria',
#  'broken hill',
#  'tuktoyaktuk',
#  'behshahr',
#  'puerto del rosario',
#  'olafsvik',
#  'jalingo',
#  'qaanaaq',
#  'ciechanow',
#  'east london',
#  'cabedelo',
#  'belaya gora',
#  'kloulklubed',
#  'mattru',
#  'puerto escondido',
#  'attawapiskat',
#  'tessalit',
#  'ambilobe',
#  'lamu',
#  'inuvik',
#  'suez',
#  'haukipudas',
#  'san patricio',
#  'qaqortoq',
#  'hobart',
#  'xuanhua',
#  'dingle',
#  'suifenhe',
#  'anadyr',
#  'micheweni',
#  'bambamarca',
#  'margate',
#  'airai',
#  'kupang',
#  'upernavik',
#  'luanshya',
#  'bar harbor',
#  'chokurdakh',
#  'warqla',
#  'grindavik',
#  'mahebourg',
#  'lopsmarka',
#  'namibe',
#  'arraial do cabo',
#  'hilo',
#  'portalegre',
#  'abnub',
#  'nakamura',
#  'faanui',
#  'grand centre',
#  'ancud',
#  'esperance',
#  'pisco',
#  'monticello',
#  'kyabe',
#  'dingtao',
#  'virginia beach',
#  'dunedin',
#  'marawi',
#  'vaitupu',
#  'portland',
#  'antalaha',
#  'mount gambier',
#  'timbiqui',
#  'fairbanks',
#  'goba',
#  'deniliquin',
#  'ocos',
#  'norman wells',
#  'kryvyy rih',
#  'amapa',
#  'khabez',
#  'tasiilaq',
#  'suining',
#  'akyab',
#  'yar-sale',
#  'krasnoselkup',
#  'cayenne',
#  'zakupne',
#  'benidorm',
#  'mahina',
#  'arawa',
#  'mayo',
#  'iqaluit',
#  'grand river south east',
#  'nishihara',
#  'mount isa',
#  'general roca',
#  'lorengau',
#  'shu',
#  'rapid valley',
#  'nuuk',
#  'cap-aux-meules',
#  'yukhnov',
#  'sisimiut',
#  'tuatapere',
#  'teguldet',
#  'mar del plata',
#  'krasnyye baki',
#  'dasoguz',
#  'haines junction',
#  'maningrida',
#  'san andres',
#  'zachagansk',
#  'victoria',
#  'oussouye',
#  'makasar',
#  'huaicheng',
#  'sao filipe',
#  'sandviken',
#  'sola',
#  'codrington',
#  'marevo',
#  'rawson',
#  'mangan',
#  'sheltozero',
#  'hamilton',
#  'aklavik',
#  'kantunilkin',
#  'bilma',
#  'douglas',
#  'amderma',
#  'morant bay',
#  'berea',
#  'kavieng',
#  'ketchikan',
#  'doha',
#  'coos bay',
#  'geraldton',
#  'tabou',
#  'viligili',
#  'klaksvik',
#  'ust-shonosha',
#  'stoyba',
#  'inhambane',
#  'tadine',
#  'ngunguru',
#  'palmas bellas',
#  'cururupu',
#  'itarema',
#  'havre',
#  'tecoanapa',
#  'mao',
#  'chateaubelair',
#  'losheim',
#  'figeac',
#  'agadez',
#  'denton',
#  'port macquarie',
#  'tsihombe',
#  'atherton',
#  'marystown',
#  'tiksi',
#  'north myrtle beach',
#  'katsuura',
#  'angoram',
#  'college',
#  'oranjemund',
#  'dhidhdhoo',
#  'provideniya',
#  'erenhot',
#  'dzhusaly',
#  'tsumeb',
#  'sentyabrskiy',
#  'tomatlan',
#  'the valley',
#  'karaul',
#  'keti bandar',
#  'saint george',
#  'rio grande',
#  'kontagora',
#  'inirida',
#  'phangnga',
#  'san isidro',
#  'vrangel',
#  'aleksandrovskoye',
#  'kiunga',
#  'cap malheureux',
#  'la palma',
#  'kodiak',
#  'caravelas',
#  'pangnirtung',
#  'luderitz',
#  'sabang',
#  'tarudant',
#  'pimenta bueno',
#  'moundou',
#  'biritiba-mirim',
#  'kishtwar',
#  'vlissingen',
#  'saint-philippe',
#  'nazare',
#  'nome',
#  'mirador',
#  'killybegs',
#  'aykhal',
#  'fukue',
#  'fortuna',
#  'milingimbi',
#  'payson',
#  'constantine',
#  'mecca',
#  'camacupa',
#  'saint-augustin',
#  'saint-pierre',
#  'birao',
#  'alice springs',
#  'gonzalez',
#  'tshikapa',
#  'mormugao',
#  'paros',
#  'qingdao',
#  'naryan-mar',
#  'khatanga',
#  'lagoa',
#  'barentsburg',
#  'tuy hoa',
#  'maiduguri',
#  'teknaf',
#  'kungurtug',
#  'danjiangkou',
#  'shache',
#  'flinders',
#  'canyon',
#  'felidhoo',
#  'mikkeli',
#  'muros',
#  'roald',
#  'husavik',
#  'tiznit',
#  'wolgast',
#  'beringovskiy',
#  'manokwari',
#  'lithakia',
#  'cantaura',
#  'bathsheba',
#  'praia da vitoria',
#  'havre-saint-pierre',
#  'jieshi',
#  'troy',
#  'marsa matruh',
#  'cidreira',
#  'rudnytsya',
#  'port-gentil',
#  'buon me thuot',
#  'puri',
#  'qasigiannguit',
#  'cherskiy',
#  'broome',
#  'peddapuram',
#  'maceio',
#  'souillac',
#  'moron',
#  'arona',
#  'maryville',
#  'zaraza',
#  'maumere',
#  'braganca',
#  'maxixe',
#  'niederkassel',
#  'sibolga',
#  'baykit',
#  'guerrero negro',
#  'wisconsin rapids',
#  'saskylakh',
#  'saint-leu',
#  'byron bay',
#  'torbay',
#  'safford',
#  'belushya guba',
#  'sioux lookout',
#  'boende',
#  'sistranda',
#  'mosquera',
#  'gull lake',
#  'salalah',
#  'lethem',
#  'yagodnoye',
#  'yeppoon',
#  'beloha',
#  'plouzane',
#  'llangefni',
#  'kharp',
#  'zykovo',
#  'khasan',
#  'nola',
#  'pontianak',
#  'natal',
#  'hami',
#  'nogliki',
#  'urumqi',
#  'coolum beach',
#  'vytegra',
#  'pengcheng',
#  'zabid',
#  'poum',
#  'bonavista',
#  'udachnyy',
#  'kevsala',
#  'kars',
#  'hurfeish',
#  'ambulu',
#  'ngukurr',
#  'kuala krai',
#  'rodental',
#  'kazalinsk',
#  'pandan',
#  'alyangula',
#  'caucaia',
#  'jibuti',
#  'bud',
#  'duz',
#  'ust-kuyga',
#  'antsohihy',
#  'meyungs',
#  'kota belud',
#  'bambous virieux',
#  'dzierzoniow',
#  'normandin',
#  'oxapampa',
#  'gaomi',
#  'lohardaga',
#  'kavaratti',
#  'williston',
#  'moche',
#  'aitape',
#  'makueni',
#  'touros',
#  'cukai',
#  'koungou',
#  'loandjili',
#  'talcahuano',
#  'gambo',
#  'walvis bay',
#  'belyy yar',
#  'shimanovsk',
#  'newport',
#  'rypefjord',
#  'russell',
#  'pochutla',
#  'satitoa',
#  'north platte',
#  'mendahara',
#  'santa cruz',
#  'biak',
#  'ozgon',
#  'kilindoni',
#  'zhicheng',
#  'neiafu',
#  'siuna',
#  'mocambique',
#  'gouyave',
#  'eldikan',
#  'waingapu',
#  'bokspits',
#  'alta floresta',
#  'brigham city',
#  'miquelon',
#  'rio gallegos',
#  'doctor pedro p. pena',
#  'sterling',
#  'roscommon',
#  'shar',
#  'longido',
#  'taoudenni',
#  'dukat',
#  'biograd na moru',
#  'eftimie murgu',
#  'lebu',
#  'talnakh',
#  'sarahan',
#  'maracacume',
#  'wiarton',
#  'luganville',
#  'tigre',
#  'zhaotong',
#  'bentiu',
#  'dmytrivka',
#  'colmenar viejo',
#  'sayat',
#  'tumannyy',
#  'garowe',
#  'palmas',
#  'kuytun',
#  'filiatra',
#  'taburao',
#  'bin qirdan',
#  'coihaique',
#  'conde',
#  'korla',
#  'saint-louis',
#  'howard springs',
#  'zhezkazgan',
#  'araouane',
#  'balclutha',
#  'dien bien',
#  'hendersonville',
#  'tual',
#  'port blair',
#  'padang',
#  'vicente guerrero',
#  'nevelsk',
#  'mkushi',
#  'hun',
#  'minab',
#  'isla mujeres',
#  'bima',
#  'tabiauea',
#  'yushu',
#  'jucas',
#  'shetpe',
#  'hasaki',
#  'brownsville',
#  'sucre',
#  'severo-kurilsk',
#  'maragogi',
#  'bibiani',
#  'mana',
#  'iranshahr',
#  'sawtell',
#  'toora-khem',
#  'namatanai',
#  'umm lajj',
#  'alfredo chaves',
#  'durazno',
#  'batemans bay',
#  'brae',
#  'caala',
#  'wahran',
#  'faya',
#  'forbes',
#  'qui nhon',
#  'clyde river',
#  'lipari',
#  'naze',
#  'port hedland',
#  'livingstonia',
#  'hualmay',
#  'santa fe',
#  'mandla',
#  'porto novo',
#  'steamboat springs',
#  'salisbury',
#  'kadayanallur',
#  'kropotkin',
#  'buchanan',
#  'maues',
#  'bonthe',
#  'fort nelson',
#  'matagami',
#  'pensilvania',
#  'ahipara',
#  'sorland',
#  'saint-junien',
#  'isangel',
#  'kudahuvadhoo',
#  'asau',
#  'tungkang',
#  'zaysan',
#  'bubaque',
#  'narayanpet',
#  'gobabis',
#  'plastun',
#  'moose factory',
#  'waipawa',
#  'nantucket',
#  'suna',
#  'shimoda',
#  'areosa',
#  'chicama',
#  'yilan',
#  'lexington',
#  'anniston',
#  'calabozo',
#  'sataua',
#  'morondava',
#  'mantua',
#  'harper',
#  'one hundred mile house',
#  'sheridan',
#  'palabuhanratu',
#  'koboldo',
#  'komsomolskiy',
#  'lenggries',
#  'vila franca do campo',
#  'antofagasta',
#  'hof',
#  'bolotnoye',
#  'havelock',
#  'ulladulla',
#  'sarangani',
#  'lujan',
#  'matara',
#  'america dourada',
#  'terracina',
#  'toliary',
#  'campbell river',
#  'dubbo',
#  'fort-shevchenko',
#  'karasjok',
#  'arlit',
#  'buraydah',
#  'prince rupert',
#  'dzhebariki-khaya',
#  'lompoc',
#  'malwan',
#  'glinka',
#  'kristiansund',
#  'saint-joseph',
#  'ambon',
#  'champa',
#  'mehamn',
#  'jatai']

# %%
# Converting to Data Frame
#cities_df = pd.DataFrame(cities)
#cities_df.head()

# %%
# Save as a csv
#cities_df.to_csv(output_data_file, encoding="utf-8", index=False)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Dependencies
#import csv
from api_keys import api_key

# %%
# Get data for each city in cities.csv
#with open("output_data/cities.csv") as cities_file:
    #cities_reader = csv.reader(cities_file)
    #cities = [city for city in cities_reader]
#print(cities)

# %%
cities
# Out:
# ['montepuez',
#  'ushuaia',
#  'rikitea',
#  'syracuse',
#  'boa vista',
#  'mweka',
#  'hermanus',
#  'punta arenas',
#  'mataura',
#  'lata',
#  'saleaula',
#  'ugoofaaru',
#  'mucuri',
#  'cockburn town',
#  'sinnamary',
#  'ponta do sol',
#  'busselton',
#  'nove mesto na morave',
#  'nelson bay',
#  'los llanos de aridane',
#  'kieta',
#  'taolanaro',
#  'tautira',
#  'kuhdasht',
#  'abha',
#  'kathmandu',
#  'puerto ayora',
#  'sitka',
#  'karratha',
#  'hithadhoo',
#  'cape town',
#  'vaini',
#  'manggar',
#  'sept-iles',
#  'coquimbo',
#  'itoman',
#  'shenjiamen',
#  'carnarvon',
#  'wanning',
#  'bengkulu',
#  'albany',
#  'port elizabeth',
#  'kashi',
#  'te anau',
#  'new norfolk',
#  'atuona',
#  'kapaa',
#  'dikson',
#  'blythe',
#  'whitehorse',
#  'kawana waters',
#  'mattawa',
#  'kharitonovo',
#  'olimpia',
#  'paamiut',
#  'cabo san lucas',
#  'bredasdorp',
#  'jamestown',
#  'miraflores',
#  'butaritari',
#  'vardo',
#  'bethel',
#  'meulaboh',
#  'kahului',
#  'moroto',
#  'barrow',
#  'ilulissat',
#  'nikolskoye',
#  'port alfred',
#  'castro',
#  'nizhneyansk',
#  'vila velha',
#  'honiara',
#  'kalmunai',
#  'khani',
#  'buala',
#  'avarua',
#  'georgetown',
#  'narsaq',
#  'morros',
#  'hammerfest',
#  'ostrovnoy',
#  'termiz',
#  'alpena',
#  'vilyuysk',
#  'port lincoln',
#  'alta gracia',
#  'hovd',
#  'teguise',
#  'alofi',
#  'umzimvubu',
#  'bandarbeyla',
#  'kenai',
#  'lolua',
#  'nanortalik',
#  'yulara',
#  'port hardy',
#  'kaitangata',
#  'ribeira grande',
#  'aguada de cima',
#  'leningradskiy',
#  'bafoulabe',
#  'marcona',
#  'illoqqortoormiut',
#  'pevek',
#  'yellowknife',
#  'bluff',
#  'mys shmidta',
#  'pacific grove',
#  'thompson',
#  'chumphon',
#  'longyearbyen',
#  'horadiz',
#  'santa quiteria',
#  'broken hill',
#  'tuktoyaktuk',
#  'behshahr',
#  'puerto del rosario',
#  'olafsvik',
#  'jalingo',
#  'qaanaaq',
#  'ciechanow',
#  'east london',
#  'cabedelo',
#  'belaya gora',
#  'kloulklubed',
#  'mattru',
#  'puerto escondido',
#  'attawapiskat',
#  'tessalit',
#  'ambilobe',
#  'lamu',
#  'inuvik',
#  'suez',
#  'haukipudas',
#  'san patricio',
#  'qaqortoq',
#  'hobart',
#  'xuanhua',
#  'dingle',
#  'suifenhe',
#  'anadyr',
#  'micheweni',
#  'bambamarca',
#  'margate',
#  'airai',
#  'kupang',
#  'upernavik',
#  'luanshya',
#  'bar harbor',
#  'chokurdakh',
#  'warqla',
#  'grindavik',
#  'mahebourg',
#  'lopsmarka',
#  'namibe',
#  'arraial do cabo',
#  'hilo',
#  'portalegre',
#  'abnub',
#  'nakamura',
#  'faanui',
#  'grand centre',
#  'ancud',
#  'esperance',
#  'pisco',
#  'monticello',
#  'kyabe',
#  'dingtao',
#  'virginia beach',
#  'dunedin',
#  'marawi',
#  'vaitupu',
#  'portland',
#  'antalaha',
#  'mount gambier',
#  'timbiqui',
#  'fairbanks',
#  'goba',
#  'deniliquin',
#  'ocos',
#  'norman wells',
#  'kryvyy rih',
#  'amapa',
#  'khabez',
#  'tasiilaq',
#  'suining',
#  'akyab',
#  'yar-sale',
#  'krasnoselkup',
#  'cayenne',
#  'zakupne',
#  'benidorm',
#  'mahina',
#  'arawa',
#  'mayo',
#  'iqaluit',
#  'grand river south east',
#  'nishihara',
#  'mount isa',
#  'general roca',
#  'lorengau',
#  'shu',
#  'rapid valley',
#  'nuuk',
#  'cap-aux-meules',
#  'yukhnov',
#  'sisimiut',
#  'tuatapere',
#  'teguldet',
#  'mar del plata',
#  'krasnyye baki',
#  'dasoguz',
#  'haines junction',
#  'maningrida',
#  'san andres',
#  'zachagansk',
#  'victoria',
#  'oussouye',
#  'makasar',
#  'huaicheng',
#  'sao filipe',
#  'sandviken',
#  'sola',
#  'codrington',
#  'marevo',
#  'rawson',
#  'mangan',
#  'sheltozero',
#  'hamilton',
#  'aklavik',
#  'kantunilkin',
#  'bilma',
#  'douglas',
#  'amderma',
#  'morant bay',
#  'berea',
#  'kavieng',
#  'ketchikan',
#  'doha',
#  'coos bay',
#  'geraldton',
#  'tabou',
#  'viligili',
#  'klaksvik',
#  'ust-shonosha',
#  'stoyba',
#  'inhambane',
#  'tadine',
#  'ngunguru',
#  'palmas bellas',
#  'cururupu',
#  'itarema',
#  'havre',
#  'tecoanapa',
#  'mao',
#  'chateaubelair',
#  'losheim',
#  'figeac',
#  'agadez',
#  'denton',
#  'port macquarie',
#  'tsihombe',
#  'atherton',
#  'marystown',
#  'tiksi',
#  'north myrtle beach',
#  'katsuura',
#  'angoram',
#  'college',
#  'oranjemund',
#  'dhidhdhoo',
#  'provideniya',
#  'erenhot',
#  'dzhusaly',
#  'tsumeb',
#  'sentyabrskiy',
#  'tomatlan',
#  'the valley',
#  'karaul',
#  'keti bandar',
#  'saint george',
#  'rio grande',
#  'kontagora',
#  'inirida',
#  'phangnga',
#  'san isidro',
#  'vrangel',
#  'aleksandrovskoye',
#  'kiunga',
#  'cap malheureux',
#  'la palma',
#  'kodiak',
#  'caravelas',
#  'pangnirtung',
#  'luderitz',
#  'sabang',
#  'tarudant',
#  'pimenta bueno',
#  'moundou',
#  'biritiba-mirim',
#  'kishtwar',
#  'vlissingen',
#  'saint-philippe',
#  'nazare',
#  'nome',
#  'mirador',
#  'killybegs',
#  'aykhal',
#  'fukue',
#  'fortuna',
#  'milingimbi',
#  'payson',
#  'constantine',
#  'mecca',
#  'camacupa',
#  'saint-augustin',
#  'saint-pierre',
#  'birao',
#  'alice springs',
#  'gonzalez',
#  'tshikapa',
#  'mormugao',
#  'paros',
#  'qingdao',
#  'naryan-mar',
#  'khatanga',
#  'lagoa',
#  'barentsburg',
#  'tuy hoa',
#  'maiduguri',
#  'teknaf',
#  'kungurtug',
#  'danjiangkou',
#  'shache',
#  'flinders',
#  'canyon',
#  'felidhoo',
#  'mikkeli',
#  'muros',
#  'roald',
#  'husavik',
#  'tiznit',
#  'wolgast',
#  'beringovskiy',
#  'manokwari',
#  'lithakia',
#  'cantaura',
#  'bathsheba',
#  'praia da vitoria',
#  'havre-saint-pierre',
#  'jieshi',
#  'troy',
#  'marsa matruh',
#  'cidreira',
#  'rudnytsya',
#  'port-gentil',
#  'buon me thuot',
#  'puri',
#  'qasigiannguit',
#  'cherskiy',
#  'broome',
#  'peddapuram',
#  'maceio',
#  'souillac',
#  'moron',
#  'arona',
#  'maryville',
#  'zaraza',
#  'maumere',
#  'braganca',
#  'maxixe',
#  'niederkassel',
#  'sibolga',
#  'baykit',
#  'guerrero negro',
#  'wisconsin rapids',
#  'saskylakh',
#  'saint-leu',
#  'byron bay',
#  'torbay',
#  'safford',
#  'belushya guba',
#  'sioux lookout',
#  'boende',
#  'sistranda',
#  'mosquera',
#  'gull lake',
#  'salalah',
#  'lethem',
#  'yagodnoye',
#  'yeppoon',
#  'beloha',
#  'plouzane',
#  'llangefni',
#  'kharp',
#  'zykovo',
#  'khasan',
#  'nola',
#  'pontianak',
#  'natal',
#  'hami',
#  'nogliki',
#  'urumqi',
#  'coolum beach',
#  'vytegra',
#  'pengcheng',
#  'zabid',
#  'poum',
#  'bonavista',
#  'udachnyy',
#  'kevsala',
#  'kars',
#  'hurfeish',
#  'ambulu',
#  'ngukurr',
#  'kuala krai',
#  'rodental',
#  'kazalinsk',
#  'pandan',
#  'alyangula',
#  'caucaia',
#  'jibuti',
#  'bud',
#  'duz',
#  'ust-kuyga',
#  'antsohihy',
#  'meyungs',
#  'kota belud',
#  'bambous virieux',
#  'dzierzoniow',
#  'normandin',
#  'oxapampa',
#  'gaomi',
#  'lohardaga',
#  'kavaratti',
#  'williston',
#  'moche',
#  'aitape',
#  'makueni',
#  'touros',
#  'cukai',
#  'koungou',
#  'loandjili',
#  'talcahuano',
#  'gambo',
#  'walvis bay',
#  'belyy yar',
#  'shimanovsk',
#  'newport',
#  'rypefjord',
#  'russell',
#  'pochutla',
#  'satitoa',
#  'north platte',
#  'mendahara',
#  'santa cruz',
#  'biak',
#  'ozgon',
#  'kilindoni',
#  'zhicheng',
#  'neiafu',
#  'siuna',
#  'mocambique',
#  'gouyave',
#  'eldikan',
#  'waingapu',
#  'bokspits',
#  'alta floresta',
#  'brigham city',
#  'miquelon',
#  'rio gallegos',
#  'doctor pedro p. pena',
#  'sterling',
#  'roscommon',
#  'shar',
#  'longido',
#  'taoudenni',
#  'dukat',
#  'biograd na moru',
#  'eftimie murgu',
#  'lebu',
#  'talnakh',
#  'sarahan',
#  'maracacume',
#  'wiarton',
#  'luganville',
#  'tigre',
#  'zhaotong',
#  'bentiu',
#  'dmytrivka',
#  'colmenar viejo',
#  'sayat',
#  'tumannyy',
#  'garowe',
#  'palmas',
#  'kuytun',
#  'filiatra',
#  'taburao',
#  'bin qirdan',
#  'coihaique',
#  'conde',
#  'korla',
#  'saint-louis',
#  'howard springs',
#  'zhezkazgan',
#  'araouane',
#  'balclutha',
#  'dien bien',
#  'hendersonville',
#  'tual',
#  'port blair',
#  'padang',
#  'vicente guerrero',
#  'nevelsk',
#  'mkushi',
#  'hun',
#  'minab',
#  'isla mujeres',
#  'bima',
#  'tabiauea',
#  'yushu',
#  'jucas',
#  'shetpe',
#  'hasaki',
#  'brownsville',
#  'sucre',
#  'severo-kurilsk',
#  'maragogi',
#  'bibiani',
#  'mana',
#  'iranshahr',
#  'sawtell',
#  'toora-khem',
#  'namatanai',
#  'umm lajj',
#  'alfredo chaves',
#  'durazno',
#  'batemans bay',
#  'brae',
#  'caala',
#  'wahran',
#  'faya',
#  'forbes',
#  'qui nhon',
#  'clyde river',
#  'lipari',
#  'naze',
#  'port hedland',
#  'livingstonia',
#  'hualmay',
#  'santa fe',
#  'mandla',
#  'porto novo',
#  'steamboat springs',
#  'salisbury',
#  'kadayanallur',
#  'kropotkin',
#  'buchanan',
#  'maues',
#  'bonthe',
#  'fort nelson',
#  'matagami',
#  'pensilvania',
#  'ahipara',
#  'sorland',
#  'saint-junien',
#  'isangel',
#  'kudahuvadhoo',
#  'asau',
#  'tungkang',
#  'zaysan',
#  'bubaque',
#  'narayanpet',
#  'gobabis',
#  'plastun',
#  'moose factory',
#  'waipawa',
#  'nantucket',
#  'suna',
#  'shimoda',
#  'areosa',
#  'chicama',
#  'yilan',
#  'lexington',
#  'anniston',
#  'calabozo',
#  'sataua',
#  'morondava',
#  'mantua',
#  'harper',
#  'one hundred mile house',
#  'sheridan',
#  'palabuhanratu',
#  'koboldo',
#  'komsomolskiy',
#  'lenggries',
#  'vila franca do campo',
#  'antofagasta',
#  'hof',
#  'bolotnoye',
#  'havelock',
#  'ulladulla',
#  'sarangani',
#  'lujan',
#  'matara',
#  'america dourada',
#  'terracina',
#  'toliary',
#  'campbell river',
#  'dubbo',
#  'fort-shevchenko',
#  'karasjok',
#  'arlit',
#  'buraydah',
#  'prince rupert',
#  'dzhebariki-khaya',
#  'lompoc',
#  'malwan',
#  'glinka',
#  'kristiansund',
#  'saint-joseph',
#  'ambon',
#  'champa',
#  'mehamn',
#  'jatai']

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

 # Build a query URL
base_url = f"{url}units={units}&appid={api_key}&q="
#query_url = base_url + listing

# %%
# List of five cities

#city_listing = cities

# base url
base_url = f"{url}units={units}&appid={api_key}&q="
                
cities2 = ['esperance',
 'vardo',
 'puerto ayora',
 'bengkulu',
 'albany',
 'thompson']
    
# List for holding response info
city_list = []
country = []
date = []
lat = []
lon = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
response_json = []

print(cities)

# loop throught the list of cities 
for city in cities:
    
    
    # Build a query URL
    query_url = base_url + city
     
    print(query_url)
    
    #for x in range(len(cities)):
    #print(f"Making request number: {x} for ID: {cities}")
    
    #print(f"Processing record: {city} for ID: {cities}")

    # Get one of the posts
    #print(url + str(cities[x]))
    #post_response = requests.get(url + str(cities[x]))
            
    
            
    # Save post's JSON
    #response_json.append(post_response.json())
    
    try:
        
            
        # Get weather data
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()
        
        # Add a one second interval between queries to stay within API query limits
        time.sleep(65)
        
        # Append the response info to each respective list
        max_temp.append(weather_json["main"]["temp_max"])
        humidity.append(weather_json["main"]["humidity"])
        city_list.append(weather_json["name"])
        country.append(weather_json["sys"]["country"])              
        date.append(weather_json["dt"])
        lat.append(weather_json["coord"]["lat"])
        lon.append(weather_json["coord"]["lon"])
        cloudiness.append(weather_json["clouds"]["all"])
        wind_speed.append(weather_json["wind"]["speed"])
        
    except KeyError:  
        print("that city is not in the database")
        
    #except ConnectionResetError:
        #print(e)
        #pass
print("loop finish")
    
    #except ConnectionResetError:
        #print("connection closed")
# Out:
# ['tasiilaq', 'lebu', 'nguiu', 'vaini', 'cabo san lucas', 'rikitea', 'avarua', 'tuktoyaktuk', 'dikson', 'galle', 'taolanaro', 'atripalda', 'shimanovsk', 'ushuaia', 'kapaa', 'alugan', 'busselton', 'san patricio', 'yar-sale', 'saskylakh', 'san carlos del zulia', 'port hardy', 'malartic', 'sentyabrskiy', 'praia', 'chapais', 'tuatapere', 'ribeira grande', 'vaitupu', 'jinchengjiang', 'khatanga', 'mutsu', 'port elizabeth', 'belmonte', 'phan thiet', 'ubeda', 'victoria', 'boddam', 'los llanos de aridane', 'alofi', 'kamenskiy', 'carnarvon', 'graham', 'hermanus', 'butaritari', 'illoqqortoormiut', 'shubarshi', 'yulara', 'barao de melgaco', 'jamestown', 'belushya guba', 'laguna', 'lompoc', 'seversk', 'bargal', 'solnechnyy', 'provideniya', 'mataura', 'yellowknife', 'barabai', 'shieli', 'san cristobal', 'kodiak', 'senneterre', 'biltine', 'inhambane', 'mahebourg', 'sola', 'boa vista', 'narsaq', 'codrington', 'tynda', 'marrakesh', 'bluff', 'new norfolk', 'lai', 'port keats', 'qaanaaq', 'punta arenas', 'barrow', 'castro', 'lavrentiya', 'kavaratti', 'bengkulu', 'bredasdorp', 'aksarka', 'dakoro', 'prince rupert', 'hobart', 'tyrma', 'piranhas', 'severo-kurilsk', 'barentsburg', 'santa luzia', 'bogale', 'mar del plata', 'margate', 'hilo', 'aleksandrovsk-sakhalinskiy', 'ucluelet', 'nogliki', 'souillac', 'vila', 'sao filipe', 'bathsheba', 'hasaki', 'lesnyye polyany', 'kavieng', 'bourbonnais', 'kamenskoye', 'tuka', 'selikhino', 'ilulissat', 'samusu', 'torbay', 'ostrovnoy', 'polunochnoye', 'clyde river', 'ullapool', 'saint-pierre', 'crossville', 'port alfred', 'cape town', 'mareeba', 'svetlogorsk', 'chitrakonda', 'thompson', 'longyearbyen', 'salalah', 'georgetown', 'iqaluit', 'mys shmidta', 'springbok', 'marica', 'petropavlovsk-kamchatskiy', 'kismayo', 'porto novo', 'kwidzyn', 'tiksi', 'raga', 'batagay', 'ancud', 'maniitsoq', 'kruisfontein', 'arman', 'bambanglipuro', 'pevek', 'tucuman', 'djambala', 'samarai', 'fort frances', 'san lazaro', 'marovoay', 'longford', 'sao joao da barra', 'caravelas', 'porto walter', 'gogrial', 'lazaro cardenas', 'albany', 'mogadishu', 'la rioja', 'sinnamary', 'belfast', 'vanimo', 'cidreira', 'saint andrews', 'yaan', 'hithadhoo', 'mount gambier', 'doume', 'port lincoln', 'dekoa', 'namibe', 'akdagmadeni', 'auki', 'tres lagoas', 'camiri', 'tremedal', 'goderich', 'antsohihy', 'cherskiy', 'guane', 'bur gabo', 'kamen-na-obi', 'puerto maldonado', 'zolotinka', 'atuona', 'calabozo', 'porto real do colegio', 'comodoro rivadavia', 'asnaes', 'cabra', 'launceston', 'anadyr', 'tsihombe', 'marinette', 'nanortalik', 'touros', 'anchorage', 'puerto ayora', 'portland', 'taltal', 'acarau', 'genhe', 'chuy', 'axim', 'aswan', 'unity', 'banda aceh', 'guerrero negro', 'buraydah', 'marcona', 'honningsvag', 'hay river', 'katsuura', 'seda', 'kenai', 'price', 'tateyama', 'vigrestad', 'vardo', 'arkhangelsk', 'purpe', 'barrhead', 'kahului', 'serenje', 'porbandar', 'hayvoron', 'sungaipenuh', 'poquoson', 'skjervoy', 'talnakh', 'barreirinhas', 'east london', 'san joaquin', 'kristiinankaupunki', 'saint-philippe', 'araguaina', 'tautira', 'airai', 'sorong', 'senekal', 'sahrak', 'kamenka', 'ginir', 'gilazi', 'gra liyia', 'nageshwari', 'werda', 'wenling', 'coquimbo', 'taksimo', 'richards bay', 'grand gaube', 'gat', 'tres palos', 'warqla', 'awbari', 'mayo', 'kaitangata', 'sitka', 'acapulco', 'villarrica', 'leningradskiy', 'yueyang', 'okhotsk', 'bubaque', 'colquiri', 'hobyo', 'usinsk', 'baker city', 'miandrivazo', 'nizhneyansk', 'ponta do sol', 'lakes entrance', 'upernavik', 'cayenne', 'catuday', 'byron bay', 'rock sound', 'moree', 'beaverlodge', 'coroata', 'strezhevoy', 'amurzet', 'verkhoyansk', 'longhua', 'mugur-aksy', 'ladispoli', 'andenes', 'saint george', 'kuche', 'gornyatskiy', 'kijang', 'lorengau', 'havelock', 'champerico', 'cogtong', 'saint-georges', 'floriano', 'eyl', 'keti bandar', 'arraial do cabo', 'basoko', 'ensley', 'saint-augustin', 'zhezkazgan', 'ciudad guayana', 'sur', 'tezu', 'marstal', 'sokolo', 'marsaxlokk', 'turkistan', 'lolua', 'paamiut', 'nik ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=nguiu
# that city is not in the database
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=galle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=taolanaro
# that city is not in the database
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=atripalda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=shimanovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=alugan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=san carlos del zulia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=malartic
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=sentyabrskiy
# that city is not in the database
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=vaitupu
# that city is not in the database
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=jinchengjiang
# that city is not in the database
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=mutsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=phan thiet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=ubeda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=boddam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=kamenskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=graham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=illoqqortoormiut
# that city is not in the database
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=shubarshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=barao de melgaco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=belushya guba
# that city is not in the database
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=seversk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=bargal
# that city is not in the database
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=barabai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=shieli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=senneterre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=boa vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=tynda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=marrakesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=lai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=port keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=bengkulu
# that city is not in the database
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=dakoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=tyrma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=piranhas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=barentsburg
# that city is not in the database
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=santa luzia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=bogale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=aleksandrovsk-sakhalinskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=ucluelet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=nogliki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=bathsheba
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# /anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# /anaconda3/lib/python3.7/http/client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# /anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# /anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# /anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     366             if read is False or not self._is_method_retryable(method):
# --> 367                 raise six.reraise(type(error), error, _stacktrace)
#     368             elif read is not None:
#
# /anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     684         if value.__traceback__ is not tb:
# --> 685             raise value.with_traceback(tb)
#     686         raise value
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# /anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#
# /anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#
# /anaconda3/lib/python3.7/http/client.py in begin(self)
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#
# /anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#
# /anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-362-53ae063e8aab> in <module>
#      54
#      55         # Get weather data
# ---> 56         weather_response = requests.get(query_url)
#      57         weather_json = weather_response.json()
#      58
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))

# %%
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=1edac4711aee2476ea38c0e4dabed173&q=victoria

# %%
print(weather_json)
# Out:
# {'coord': {'lon': -151.75, 'lat': -16.48}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 80.11, 'pressure': 1010.67, 'humidity': 100, 'temp_min': 80.11, 'temp_max': 80.11, 'sea_level': 1010.67, 'grnd_level': 1010.65}, 'wind': {'speed': 7.4, 'deg': 114.501}, 'rain': {'3h': 1.265}, 'clouds': {'all': 92}, 'dt': 1551499342, 'sys': {'message': 0.0035, 'country': 'PF', 'sunrise': 1551542831, 'sunset': 1551587441}, 'id': 4034551, 'name': 'Faanui', 'cod': 200}

# %%
print(len(max_temp))
# Out:
# 100

# %%
max_temp
# Out:
# [78.31,
#  28.68,
#  70.84,
#  50,
#  -4.01,
#  42.8,
#  75.7,
#  66.2,
#  33.8,
#  83.08,
#  62.16,
#  88.48,
#  60.01,
#  -11.01,
#  30.2,
#  86,
#  54,
#  82.09,
#  51.01,
#  -9.41,
#  100,
#  2.26,
#  69.8,
#  78.81,
#  82.4,
#  39.66,
#  61,
#  28.99,
#  82,
#  52.3,
#  68,
#  15.58,
#  1.05,
#  73.4,
#  82.23,
#  62.34,
#  66.7,
#  75.2,
#  76.15,
#  65.71,
#  75.2,
#  21.99,
#  11.94,
#  57.2,
#  96.09,
#  73.4,
#  17.6,
#  55.4,
#  59,
#  64.99,
#  15.81,
#  69.8,
#  68,
#  30.99,
#  64.99,
#  24.01,
#  -16.87,
#  -1.84,
#  68,
#  82.54,
#  77,
#  10.59,
#  25,
#  81.01,
#  75.99,
#  -23.84,
#  34,
#  71.6,
#  25.3,
#  86,
#  63.06,
#  25.03,
#  67.56,
#  69.8,
#  64.4,
#  55.99,
#  66.99,
#  55.99,
#  76.47,
#  15.8,
#  -8.68,
#  57,
#  73.77,
#  49.56,
#  77.95,
#  51.8,
#  55.4,
#  46.4,
#  71.16,
#  54.69,
#  -12.73,
#  23.46,
#  32,
#  80.01,
#  51.8,
#  61.39,
#  64.41,
#  46.4,
#  66.61,
#  86,
#  77.05,
#  6.8,
#  30.03,
#  99,
#  79.98,
#  21.79,
#  78.8,
#  50.19,
#  19.99,
#  73.4,
#  51.8,
#  5,
#  78.8,
#  70.3,
#  79,
#  71.6,
#  86,
#  84.2,
#  26.6,
#  6.72,
#  44.6,
#  96.8,
#  26.2,
#  31.56,
#  -9.01,
#  48.99,
#  52.39,
#  50.91,
#  79,
#  65.04,
#  83.67,
#  43.71,
#  75.61,
#  6.8,
#  62.01,
#  65.49,
#  87.63,
#  84,
#  -11.01,
#  78.63,
#  28.68,
#  73.4,
#  68.64,
#  -4.4,
#  -0.41,
#  78.18,
#  55,
#  61.03,
#  4.51,
#  30.99,
#  68.01,
#  81.06,
#  82.36,
#  17.38,
#  71.01,
#  45,
#  42.63,
#  50,
#  39.2,
#  23.41,
#  57.99,
#  68.91,
#  6.36,
#  32.14,
#  71.01,
#  -3.77,
#  48.99,
#  44.6,
#  58.33,
#  26.61,
#  65.35,
#  79.3,
#  24.01,
#  71.52,
#  17.6,
#  80.01,
#  71.6,
#  31.6,
#  39,
#  82.9,
#  60.8,
#  78.8,
#  23.41,
#  78.8,
#  57.99,
#  83.49,
#  79.66,
#  21.99,
#  84.2,
#  70,
#  54,
#  82.4,
#  80.11,
#  39.2,
#  104,
#  72.69,
#  62.01,
#  40.06,
#  32.23,
#  -17.09,
#  73.4,
#  51.8,
#  33.8,
#  75.66,
#  66.2,
#  39,
#  81.1,
#  74.94,
#  -0.76,
#  68.95,
#  82.99,
#  75.2,
#  34.48,
#  39.99,
#  64,
#  77,
#  57.2,
#  82.4,
#  -11.21,
#  34.08,
#  77,
#  71.88,
#  95,
#  84.34,
#  73.4,
#  76.74,
#  77.86,
#  -8.09,
#  77.19,
#  50.05,
#  18.55,
#  6.01,
#  24.01,
#  55.4,
#  74.67,
#  55.99,
#  -0.41,
#  57.2,
#  61.21,
#  75.2,
#  55.99,
#  -11.21,
#  84.2,
#  25,
#  48.2,
#  54.51,
#  7.53,
#  71.6,
#  74.71,
#  46.4,
#  3,
#  30.2,
#  62.74,
#  51.8,
#  57,
#  44.01,
#  72.1,
#  51.8,
#  86,
#  72,
#  44.01,
#  63,
#  75.2,
#  33.8,
#  72.87,
#  91.4,
#  81.78,
#  9.06,
#  59.86,
#  22.74,
#  70.98,
#  0.55,
#  57.99,
#  84.2,
#  84.2,
#  76.06,
#  82.4,
#  22.06,
#  48.34,
#  68,
#  14.95,
#  55.4,
#  44.01,
#  3.48,
#  45,
#  53.01,
#  10.4,
#  51.18,
#  68.19,
#  78.8,
#  70,
#  69.01,
#  95,
#  82.4,
#  28.99,
#  21.2,
#  1.77,
#  57.61,
#  1.4,
#  64.4,
#  86,
#  75.57,
#  34,
#  80.79,
#  73.54,
#  74.98,
#  77.41,
#  83.58,
#  47.58,
#  63,
#  57.2,
#  73,
#  70.84,
#  57.2,
#  31.24,
#  26.01,
#  3.84,
#  15.04,
#  46.4,
#  68,
#  71.43,
#  84.2,
#  72.42,
#  -13.09,
#  63.06,
#  84.99,
#  28.99,
#  20.58,
#  63.64,
#  68.28,
#  81.1,
#  73.4,
#  69.8,
#  38.44,
#  81.51,
#  57.2]

# %%
print(len(humidity))
# Out:
# 336

# %%
humidity
# Out:
# [100,
#  93,
#  95,
#  76,
#  64,
#  100,
#  100,
#  45,
#  100,
#  100,
#  82,
#  36,
#  87,
#  62,
#  68,
#  62,
#  46,
#  100,
#  93,
#  69,
#  10,
#  100,
#  77,
#  79,
#  83,
#  68,
#  70,
#  63,
#  98,
#  51,
#  88,
#  100,
#  60,
#  94,
#  100,
#  92,
#  95,
#  78,
#  96,
#  62,
#  49,
#  73,
#  84,
#  93,
#  23,
#  60,
#  72,
#  82,
#  58,
#  93,
#  83,
#  54,
#  82,
#  42,
#  100,
#  72,
#  70,
#  80,
#  82,
#  100,
#  94,
#  77,
#  62,
#  100,
#  26,
#  35,
#  80,
#  94,
#  100,
#  74,
#  29,
#  87,
#  84,
#  88,
#  52,
#  100,
#  83,
#  87,
#  91,
#  61,
#  64,
#  37,
#  89,
#  76,
#  45,
#  87,
#  71,
#  93,
#  76,
#  94,
#  79,
#  98,
#  73,
#  74,
#  29,
#  88,
#  56,
#  87,
#  66,
#  74,
#  75,
#  65,
#  77,
#  10,
#  100,
#  100,
#  78,
#  46,
#  67,
#  72,
#  93,
#  60,
#  78,
#  42,
#  88,
#  73,
#  74,
#  62,
#  92,
#  85,
#  93,
#  47,
#  89,
#  84,
#  76,
#  65,
#  54,
#  63,
#  78,
#  100,
#  96,
#  75,
#  90,
#  84,
#  69,
#  90,
#  94,
#  51,
#  69,
#  100,
#  97,
#  94,
#  48,
#  65,
#  70,
#  100,
#  86,
#  84,
#  58,
#  86,
#  85,
#  88,
#  54,
#  82,
#  100,
#  93,
#  73,
#  93,
#  29,
#  92,
#  22,
#  99,
#  78,
#  96,
#  56,
#  75,
#  80,
#  70,
#  97,
#  90,
#  96,
#  100,
#  52,
#  93,
#  67,
#  71,
#  88,
#  53,
#  93,
#  97,
#  87,
#  83,
#  45,
#  74,
#  82,
#  97,
#  68,
#  92,
#  74,
#  65,
#  40,
#  78,
#  100,
#  64,
#  12,
#  82,
#  63,
#  29,
#  48,
#  24,
#  18,
#  93,
#  37,
#  94,
#  88,
#  93,
#  93,
#  98,
#  66,
#  95,
#  51,
#  78,
#  83,
#  92,
#  60,
#  94,
#  71,
#  83,
#  69,
#  88,
#  73,
#  70,
#  44,
#  81,
#  49,
#  100,
#  89,
#  77,
#  83,
#  58,
#  64,
#  70,
#  92,
#  76,
#  94,
#  87,
#  54,
#  87,
#  96,
#  88,
#  43,
#  76,
#  74,
#  100,
#  81,
#  100,
#  73,
#  53,
#  100,
#  65,
#  86,
#  79,
#  77,
#  87,
#  33,
#  100,
#  28,
#  23,
#  58,
#  60,
#  96,
#  87,
#  100,
#  86,
#  100,
#  31,
#  86,
#  60,
#  84,
#  100,
#  92,
#  71,
#  87,
#  79,
#  66,
#  91,
#  83,
#  73,
#  97,
#  64,
#  76,
#  37,
#  93,
#  61,
#  75,
#  100,
#  66,
#  81,
#  60,
#  69,
#  65,
#  53,
#  12,
#  61,
#  86,
#  57,
#  67,
#  64,
#  49,
#  77,
#  66,
#  100,
#  79,
#  75,
#  95,
#  31,
#  89,
#  62,
#  73,
#  79,
#  15,
#  88,
#  92,
#  43,
#  92,
#  67,
#  78,
#  78,
#  93,
#  20,
#  96,
#  74,
#  81,
#  57,
#  100,
#  48,
#  83,
#  67,
#  92,
#  98,
#  90,
#  69,
#  19,
#  100,
#  91,
#  41]

# %%
print(len(lat))
# Out:
# 336

# %%
lat
# Out:
# [-23.12,
#  56.69,
#  -12.74,
#  -54.81,
#  69.44,
#  62.23,
#  -23.78,
#  25.36,
#  60.79,
#  -0.6,
#  17.43,
#  -23.58,
#  -34.53,
#  62.45,
#  42.91,
#  5.28,
#  33.32,
#  -5.67,
#  -53.16,
#  58.81,
#  -42.88,
#  72.79,
#  -20.22,
#  -8.93,
#  -20.21,
#  33.6,
#  -46.19,
#  42.65,
#  -0.74,
#  18.9,
#  19.1,
#  70.98,
#  65.85,
#  -17.66,
#  3.07,
#  38.52,
#  -20.63,
#  17.01,
#  -1.2,
#  -46.28,
#  22.08,
#  59.7,
#  69.49,
#  -51.62,
#  -33.21,
#  -34.68,
#  45.36,
#  -1.22,
#  8.96,
#  -34.42,
#  59.1,
#  15.34,
#  -33.02,
#  39.95,
#  30.44,
#  43.64,
#  77.48,
#  73.51,
#  -33.93,
#  4.14,
#  -5.2,
#  65.53,
#  38.51,
#  -9.8,
#  -33.64,
#  71.97,
#  39.62,
#  26.19,
#  50.68,
#  -3.41,
#  10.97,
#  63.05,
#  -6.28,
#  -20.25,
#  -39.03,
#  41.81,
#  -33.59,
#  35.21,
#  -16.84,
#  65.61,
#  67.46,
#  35.73,
#  -14.45,
#  -30.97,
#  17.41,
#  -42.48,
#  32.45,
#  44.11,
#  17.88,
#  -46.43,
#  70.62,
#  65.58,
#  64.75,
#  15.74,
#  37.57,
#  -34,
#  -38.31,
#  37.89,
#  -17.5,
#  -21.21,
#  -0.9,
#  78.22,
#  56.08,
#  -42.78,
#  -6.22,
#  70.86,
#  4.94,
#  13.58,
#  47.66,
#  21.44,
#  47.55,
#  49.72,
#  17.65,
#  27.52,
#  -3.71,
#  3.25,
#  -19.06,
#  10.21,
#  43.28,
#  69.7,
#  45.69,
#  -20.31,
#  57.34,
#  61.99,
#  50.65,
#  39.34,
#  18.74,
#  27.75,
#  8.72,
#  -10.99,
#  -21.64,
#  29.14,
#  -4.26,
#  44.9,
#  -46.13,
#  -14.06,
#  -14.25,
#  -25.3,
#  63.75,
#  11.72,
#  64.42,
#  6.8,
#  -31.54,
#  71.64,
#  70.47,
#  -5.12,
#  43.56,
#  -26.65,
#  66.42,
#  59.61,
#  20.47,
#  12.18,
#  17.54,
#  58.71,
#  25.87,
#  51.31,
#  7.01,
#  45.6,
#  60.91,
#  57.69,
#  36.31,
#  -8.42,
#  60.75,
#  49.63,
#  -43.53,
#  66.83,
#  39.45,
#  27.18,
#  -42.77,
#  32.93,
#  2.14,
#  -14.27,
#  45.62,
#  -28.77,
#  63.59,
#  -41.05,
#  -24.79,
#  48.28,
#  63.84,
#  -7.76,
#  37.73,
#  -22.28,
#  29.28,
#  13.07,
#  34.64,
#  -2.02,
#  3.87,
#  44.51,
#  11.67,
#  -35.62,
#  35.55,
#  8.5,
#  -16.48,
#  40.83,
#  -25.24,
#  -34.72,
#  -36.89,
#  49.49,
#  40.29,
#  71.98,
#  29.56,
#  44.83,
#  43.32,
#  1.74,
#  -18.4,
#  39.31,
#  5.56,
#  -9.01,
#  66.77,
#  -7.53,
#  -27.56,
#  10.24,
#  38.94,
#  63.83,
#  30.73,
#  -12.18,
#  36.62,
#  -20.41,
#  55.74,
#  43.35,
#  22.83,
#  -33.69,
#  -15.77,
#  -8.15,
#  20.89,
#  9.49,
#  -2.76,
#  68.75,
#  7.38,
#  28.21,
#  51.27,
#  50.2,
#  44.08,
#  37.14,
#  -2.92,
#  37.68,
#  68.22,
#  -0.39,
#  -10.88,
#  26.68,
#  39.86,
#  69.47,
#  6.12,
#  47.48,
#  48.86,
#  39.09,
#  49.22,
#  19.71,
#  -11.2,
#  34.16,
#  49.18,
#  42.61,
#  -26.98,
#  -41.87,
#  35.83,
#  44.07,
#  12.18,
#  38,
#  10.31,
#  22.89,
#  54.11,
#  30.04,
#  -0.12,
#  41.96,
#  -22.97,
#  -23.53,
#  10.35,
#  59.7,
#  3.3,
#  47.57,
#  14.9,
#  65.44,
#  38.18,
#  -12.98,
#  7.04,
#  5.43,
#  -20.34,
#  39.02,
#  -1.64,
#  15.28,
#  61.68,
#  33.72,
#  51.5,
#  65.99,
#  34.8,
#  41.92,
#  71,
#  14.4,
#  -34.48,
#  17.93,
#  -35.1,
#  28.39,
#  -31.97,
#  -28.95,
#  50.04,
#  53.05,
#  60.47,
#  29.18,
#  65.28,
#  -21.67,
#  -16.99,
#  -15.19,
#  59.51,
#  5.66,
#  -13.28,
#  -33.3,
#  -0.13,
#  11,
#  36.1,
#  -38.55,
#  18.08,
#  23.22,
#  -18.36,
#  34.7,
#  53.67,
#  64.84,
#  58.38,
#  60.87,
#  31.4,
#  23.99,
#  5.43,
#  -0.02,
#  19.61,
#  52.84,
#  -3.38,
#  -34.67,
#  37.17,
#  55.15,
#  8.41,
#  -2.52,
#  8.06,
#  -27.17,
#  36.21,
#  64.25,
#  10.18,
#  41.35]

# %%
print(len(lon))
# Out:
# 336

# %%
lon
# Out:
# [-134.97,
#  54.35,
#  -60.15,
#  -68.31,
#  -133.03,
#  -6.59,
#  -45.36,
#  55.39,
#  -161.76,
#  73.08,
#  -99.15,
#  149.07,
#  20.04,
#  -114.38,
#  -82.49,
#  115.24,
#  129.49,
#  132.75,
#  -70.91,
#  -122.69,
#  147.33,
#  -56.15,
#  -70.14,
#  125.41,
#  57.76,
#  56.92,
#  168.86,
#  -73.75,
#  -90.35,
#  -3.53,
#  37.33,
#  25.97,
#  44.24,
#  -62.72,
#  172.79,
#  -28.7,
#  -46,
#  54.1,
#  -46.02,
#  169.85,
#  -159.32,
#  30.79,
#  88.39,
#  -69.22,
#  138.6,
#  -56.22,
#  -73.48,
#  -78.6,
#  38.73,
#  19.24,
#  26.19,
#  74.49,
#  27.91,
#  -94.76,
#  -84.28,
#  -72.25,
#  -69.36,
#  80.55,
#  18.42,
#  96.13,
#  -35.46,
#  72.51,
#  43.37,
#  -139.03,
#  115.35,
#  114.09,
#  -77.74,
#  -97.7,
#  156.12,
#  114.85,
#  -3.25,
#  179.32,
#  143.99,
#  -43.81,
#  -67.58,
#  -8.85,
#  26.89,
#  -118.83,
#  36.99,
#  -37.64,
#  153.71,
#  140.83,
#  -56.8,
#  22.13,
#  121.44,
#  -73.76,
#  -99.73,
#  1.08,
#  76.95,
#  -67.52,
#  147.9,
#  -170.99,
#  20.95,
#  -96.47,
#  126.98,
#  24.73,
#  -60.23,
#  58.52,
#  24.28,
#  -159.78,
#  119.87,
#  15.63,
#  99.63,
#  147.06,
#  155.63,
#  29.09,
#  -52.33,
#  -8.03,
#  -52.73,
#  -157.84,
#  -2.56,
#  -86.95,
#  83.27,
#  -110.01,
#  -38.6,
#  -76.23,
#  -169.92,
#  106.33,
#  142.47,
#  170.27,
#  5.91,
#  118.58,
#  58.22,
#  -49.67,
#  -104.86,
#  22.42,
#  7.39,
#  -107.63,
#  -79.89,
#  26.74,
#  -41.05,
#  21.3,
#  -55.99,
#  -97.12,
#  167.69,
#  32.43,
#  129.55,
#  152.85,
#  -68.52,
#  122.09,
#  -173.23,
#  -58.16,
#  -68.53,
#  128.87,
#  -68.59,
#  120.25,
#  6.97,
#  15.16,
#  112.4,
#  11.09,
#  84.23,
#  125.51,
#  120.52,
#  81.5,
#  -97.51,
#  4.43,
#  39.97,
#  -0.6,
#  -46.05,
#  93.28,
#  139.8,
#  20.74,
#  -137.51,
#  41.73,
#  172.64,
#  70.83,
#  22.34,
#  31.19,
#  -65.04,
#  66.63,
#  27.99,
#  50.17,
#  -61.36,
#  32.06,
#  -135.9,
#  145.91,
#  -65.41,
#  129.53,
#  -22.43,
#  113.42,
#  -25.67,
#  166.46,
#  82.18,
#  -59.53,
#  -120.46,
#  147.27,
#  -67.92,
#  -80.02,
#  92.75,
#  174.5,
#  133.23,
#  -82.29,
#  -151.75,
#  -115.76,
#  130.99,
#  135.86,
#  -60.32,
#  105.92,
#  97.04,
#  102.47,
#  -104.41,
#  -0.61,
#  145.57,
#  98.78,
#  47.88,
#  -74.98,
#  95.32,
#  -35.22,
#  123.37,
#  -46.04,
#  152.28,
#  -61.45,
#  100.46,
#  10.7,
#  -112.95,
#  136.78,
#  -121.92,
#  57.7,
#  -97.86,
#  52.85,
#  108.3,
#  -53.46,
#  128.74,
#  159.59,
#  -156.47,
#  50.81,
#  -42.27,
#  161.3,
#  8.57,
#  83.99,
#  27.23,
#  -66.38,
#  -80.2,
#  -8.45,
#  -39.92,
#  -121.77,
#  -135.01,
#  -78.55,
#  26.6,
#  -80.67,
#  116.51,
#  25.52,
#  81.12,
#  -55.8,
#  2.35,
#  17.12,
#  -84.78,
#  -155.08,
#  13.84,
#  113.47,
#  -100.5,
#  -71.57,
#  -56.83,
#  -73.83,
#  137.95,
#  9.91,
#  6.51,
#  140.58,
#  119.01,
#  -109.91,
#  -9.15,
#  -94.42,
#  -51.29,
#  42.96,
#  -42.02,
#  148.16,
#  107.08,
#  150.17,
#  32.88,
#  -59.14,
#  -24.5,
#  52.15,
#  -1.13,
#  -38.48,
#  134.26,
#  -2.14,
#  57.76,
#  31.15,
#  -78.74,
#  -23.77,
#  96.39,
#  135.99,
#  6.55,
#  60.32,
#  -87.68,
#  3.16,
#  24.66,
#  46.47,
#  -54.34,
#  -76.27,
#  173.78,
#  -105.62,
#  141.45,
#  153.24,
#  20.52,
#  158.65,
#  166.1,
#  74.77,
#  -126.83,
#  -64.63,
#  145.42,
#  12.15,
#  15.99,
#  -67.63,
#  -50.16,
#  -66.34,
#  -67.09,
#  122.67,
#  0.42,
#  -58.74,
#  -15.98,
#  -106.42,
#  -44.46,
#  138.93,
#  102.31,
#  -147.72,
#  42.35,
#  60.43,
#  30.42,
#  -104.67,
#  7.07,
#  109.34,
#  84.67,
#  -110.86,
#  35.86,
#  150.86,
#  -99.65,
#  124.74,
#  48.48,
#  32.9,
#  -78.36,
#  -58.42,
#  -115.07,
#  -15.21,
#  119.24,
#  -1.64]

# %%
print(len(city_list))
# Out:
# 336

# %%
city_list
# Out:
# ['Rikitea',
#  'Foki',
#  'Vilhena',
#  'Ushuaia',
#  'Tuktoyaktuk',
#  'Klaksvik',
#  'Ilhabela',
#  'Sharjah',
#  'Bethel',
#  'Hithadhoo',
#  'Juxtlahuaca',
#  'Bluff',
#  'Bredasdorp',
#  'Yellowknife',
#  'Marysville',
#  'Victoria',
#  'Hirado',
#  'Tual',
#  'Punta Arenas',
#  'Fort Nelson',
#  'Hobart',
#  'Upernavik',
#  'Iquique',
#  'Airai',
#  'Quatre Cocos',
#  'Tabas',
#  'Mataura',
#  'Albany',
#  'Puerto Ayora',
#  'Araouane',
#  'Sawakin',
#  'Honningsvag',
#  'Mezen',
#  'Pailon',
#  'Butaritari',
#  'Ribeira Grande',
#  'Ponta do Sol',
#  'Salalah',
#  'Carutapera',
#  'Kaitangata',
#  'Kapaa',
#  'Nikolskoye',
#  'Talnakh',
#  'Rio Gallegos',
#  'Jamestown',
#  'Progreso',
#  'Saint-Philippe',
#  'Atocha',
#  'Lebu',
#  'Hermanus',
#  'Vao',
#  'Vaini',
#  'East London',
#  'Kodiak',
#  'Tallahassee',
#  'Lebanon',
#  'Qaanaaq',
#  'Dikson',
#  'Cape Town',
#  'Meulaboh',
#  'Touros',
#  'Nadym',
#  'Van',
#  'Atuona',
#  'Busselton',
#  'Saskylakh',
#  'Vardo',
#  'Harlingen',
#  'Severo-Kurilsk',
#  'Martapura',
#  'Diebougou',
#  'Beringovskiy',
#  'Ialibu',
#  'Praia',
#  'General Roca',
#  'Vila Praia de Ancora',
#  'Port Alfred',
#  'Arvin',
#  'Mocuba',
#  'Tasiilaq',
#  'Srednekolymsk',
#  'Hasaki',
#  'Nortelandia',
#  'Carnarvon',
#  'Tabuk',
#  'Castro',
#  'Abilene',
#  'Moissac',
#  'Basavakalyana',
#  'Mar del Plata',
#  'Chokurdakh',
#  'Lavrentiya',
#  'Skelleftea',
#  'Pochutla',
#  'Seoul',
#  'Kruisfontein',
#  'Barrow',
#  'Annau',
#  'Katima Mulilo',
#  'Avarua',
#  'Palu',
#  'Longyearbyen',
#  'Chunskiy',
#  'New Norfolk',
#  'Kieta',
#  'Berlevag',
#  'Cayenne',
#  'Kolokani',
#  'Torbay',
#  'Ahuimanu',
#  'Ambon',
#  'Geraldton',
#  'Yarada',
#  'Laguna',
#  'Vila Velha',
#  'Miranda',
#  'Alofi',
#  'Thanh Hoa',
#  'Furano',
#  'Pevek',
#  'Aix-les-Bains',
#  'Port Hedland',
#  'Shamary',
#  'Paamiut',
#  'Lumsden',
#  'Vamvakou',
#  'Arlit',
#  'Creel',
#  'Campana',
#  'Likasi',
#  'Sao Joao da Barra',
#  'Awjilah',
#  'Itaituba',
#  'Watertown',
#  'Tuatapere',
#  'Chadiza',
#  'Port Keats',
#  'Hervey Bay',
#  'Iqaluit',
#  'Pandan',
#  'Provideniya',
#  'Georgetown',
#  'San Juan',
#  'Tiksi',
#  'Clyde River',
#  'Sinjai',
#  'Saint-Joseph',
#  'Luderitz',
#  'Udachnyy',
#  'Spydeberg',
#  'Phulabani',
#  'San Policarpo',
#  'San Quintin',
#  'Parabel',
#  'Matamoros',
#  'Kapellen',
#  'Goba',
#  'Souillac',
#  'Narsaq',
#  'Kazachinskoye',
#  'Oyama',
#  'Lucapa',
#  'Haines Junction',
#  'Veshenskaya',
#  'Christchurch',
#  'Yar-Sale',
#  'Saint George',
#  'Asyut',
#  'Puerto Madryn',
#  'Uruzgan',
#  'Wamba',
#  'Sambava',
#  'Port Hawkesbury',
#  'Richards Bay',
#  'Mayo',
#  'Burnie',
#  'Salta',
#  'Xinqing',
#  'Grindavik',
#  'Kraksaan',
#  'Ponta Delgada',
#  'Noumea',
#  'Jumla',
#  'Oistins',
#  'Lompoc',
#  'Lorengau',
#  'Inirida',
#  'Wasaga Beach',
#  'Port Blair',
#  'Ngunguru',
#  'Sakaiminato',
#  'Higueron',
#  'Faanui',
#  'Elko',
#  'Yulara',
#  'Port Lincoln',
#  'Olavarria',
#  'Darhan',
#  'Yumen',
#  'Khatanga',
#  'Ojinaga',
#  'Saint-Augustin',
#  'Nemuro',
#  'Sibolga',
#  'Anjozorobe',
#  'Port Elizabeth',
#  'Banda Aceh',
#  'Maragogi',
#  'Zhigansk',
#  'Balsas',
#  'Gatton',
#  'Esperance',
#  'Zhangye',
#  'Hovd',
#  'Ures',
#  'Nhulunbuy',
#  'Pacific Grove',
#  'Mahebourg',
#  'Thompson',
#  'Zhanaozen',
#  'Nanning',
#  'Chuy',
#  'Kununurra',
#  'Buala',
#  'Kahului',
#  'Bandarbeyla',
#  'Tutoia',
#  'Cherskiy',
#  'Yaan',
#  'Pokhara',
#  'Rokytne',
#  'Sept-Iles',
#  'Shelburne',
#  'Lagoa',
#  'Itarema',
#  'Livermore',
#  'Aklavik',
#  'San Cristobal',
#  'Kambove',
#  'Belle Glade',
#  'Taozhuang',
#  'Karasjok',
#  'Hambantota',
#  'Harbour Breton',
#  'Paris',
#  'Crotone',
#  'Hornepayne',
#  'Hilo',
#  'Sumbe',
#  'Yuzhou',
#  'Deloraine',
#  'Groton',
#  'San Patricio',
#  'Ancud',
#  'Ina',
#  'Lerici',
#  'Auki',
#  'Shiroishi',
#  'Caruray',
#  'Cabo San Lucas',
#  'Ballina',
#  'Nome',
#  'Mazagao',
#  'Khani',
#  'Arraial do Cabo',
#  'Emerald',
#  'Vung Tau',
#  'Arman',
#  'Kitgum',
#  'Channel-Port aux Basques',
#  'Sao Filipe',
#  'Ust-Tsilma',
#  'Fortuna',
#  'Salvador',
#  'Kloulklubed',
#  'Prestea',
#  'Bambous Virieux',
#  'Emirdag',
#  'La Asuncion',
#  'Tarrafal',
#  'Baykit',
#  'Shingu',
#  'Kamp-Lintfort',
#  'Verkhnyaya Inta',
#  'Florence',
#  'Palafrugell',
#  'Havoysund',
#  'Marzuq',
#  'Rocha',
#  'Orange Walk',
#  'Kaeo',
#  'Lazaro Cardenas',
#  'Broken Hill',
#  'Codrington',
#  'Zatoka',
#  'Petropavlovsk-Kamchatskiy',
#  'Tilichiki',
#  'Nohar',
#  'Norman Wells',
#  'Media Luna',
#  'Mareeba',
#  'Namibe',
#  'Koping',
#  'Puerto Ayacucho',
#  'Sao Miguel do Araguaia',
#  'San Luis',
#  'Sao Gabriel da Cachoeira',
#  'Dingle',
#  'Sidi Ali',
#  'Necochea',
#  'Nouakchott',
#  'Mazatlan',
#  'Corinto',
#  'Shimoda',
#  'Tyret Pervaya',
#  'Fairbanks',
#  'Galich',
#  'Polunochnoye',
#  'Rosetta',
#  'Constitucion',
#  'Naze',
#  'Pontianak',
#  'Aska',
#  'Wainwright',
#  'Mto wa Mbu',
#  'Kiama',
#  'Sitka',
#  'Tynda',
#  'Garowe',
#  'Mwanza',
#  'Garachine',
#  'General Jose Eduvigis Diaz',
#  'Sunrise Manor',
#  'Hofn',
#  'Caramay',
#  'Calatayud']

# %%
print(len(wind_speed))
# Out:
# 336

# %%
wind_speed
# Out:
# [13,
#  5.73,
#  2.15,
#  2.82,
#  16.11,
#  10.29,
#  6.96,
#  24.16,
#  6.93,
#  9.53,
#  1.81,
#  13.11,
#  1.12,
#  8.05,
#  3.36,
#  3.36,
#  5.82,
#  10.42,
#  3.36,
#  2.24,
#  19.46,
#  8.63,
#  6.93,
#  2.26,
#  10.29,
#  4.5,
#  8.99,
#  4.16,
#  6.62,
#  10.2,
#  9.17,
#  4.61,
#  4.94,
#  4.7,
#  13.89,
#  22.84,
#  2.71,
#  2.24,
#  3.49,
#  11.1,
#  14.99,
#  4.47,
#  20.27,
#  5.82,
#  9.19,
#  16.11,
#  2.71,
#  4.7,
#  2.24,
#  3.04,
#  9.53,
#  3.36,
#  3.36,
#  12.75,
#  4.7,
#  2.15,
#  5.39,
#  18.48,
#  2.24,
#  2.93,
#  3.36,
#  3.27,
#  5.82,
#  6.62,
#  7.07,
#  2.93,
#  5.82,
#  5.82,
#  8.41,
#  5.82,
#  6.73,
#  14.79,
#  2.71,
#  4.7,
#  2.24,
#  5.82,
#  1.01,
#  1.7,
#  3.38,
#  27.51,
#  5.61,
#  9.17,
#  5.84,
#  2.93,
#  2.37,
#  4.7,
#  9.17,
#  2.24,
#  10.31,
#  5.61,
#  10.76,
#  6.06,
#  10.29,
#  8.08,
#  3.36,
#  6.73,
#  21.5,
#  4.7,
#  1.92,
#  5.82,
#  1.59,
#  11.41,
#  4.94,
#  18.34,
#  4.05,
#  7.96,
#  5.82,
#  6.62,
#  25.28,
#  8.05,
#  6.93,
#  3.94,
#  8.05,
#  2.48,
#  12.75,
#  9.17,
#  9.17,
#  10.29,
#  9.17,
#  4.5,
#  1.81,
#  13.87,
#  8.63,
#  6.62,
#  13.87,
#  3.36,
#  12.21,
#  3.15,
#  5.82,
#  2.59,
#  19.6,
#  2.93,
#  1.48,
#  10.29,
#  8.99,
#  2.15,
#  6.4,
#  21.92,
#  18.34,
#  14.23,
#  22.06,
#  4.7,
#  3.15,
#  3.04,
#  17.22,
#  2.04,
#  3.36,
#  15.68,
#  2.82,
#  5.82,
#  4.16,
#  10.98,
#  3.6,
#  6.4,
#  5.82,
#  3.36,
#  2.93,
#  9.17,
#  12.75,
#  4.5,
#  5.82,
#  2.15,
#  1.92,
#  9.64,
#  9.17,
#  2.15,
#  4.7,
#  4.7,
#  4.83,
#  2.48,
#  2.04,
#  7.29,
#  8.05,
#  4.27,
#  10.29,
#  11.01,
#  4.7,
#  3.04,
#  12.75,
#  4.27,
#  17.22,
#  23.04,
#  1.92,
#  20.8,
#  5.82,
#  8.41,
#  3.38,
#  2.24,
#  8.05,
#  11.01,
#  8.05,
#  3.36,
#  7.4,
#  3.49,
#  6.93,
#  17.02,
#  4,
#  9.86,
#  5.17,
#  3.38,
#  4.7,
#  8.05,
#  12.75,
#  2.37,
#  8.05,
#  10.29,
#  2.59,
#  2.93,
#  3.71,
#  2.82,
#  16.11,
#  6.62,
#  4.38,
#  17.22,
#  1.99,
#  10.29,
#  3.36,
#  10.29,
#  5.82,
#  3.15,
#  4.47,
#  13.33,
#  8.05,
#  3.71,
#  9.17,
#  7.07,
#  4.72,
#  6.51,
#  6.51,
#  2.82,
#  10.54,
#  4.7,
#  2.24,
#  5.82,
#  4.16,
#  2.93,
#  8.05,
#  3.36,
#  2.71,
#  6.4,
#  2.24,
#  2.24,
#  12.75,
#  11.99,
#  6.93,
#  7.74,
#  4.72,
#  14.99,
#  1.36,
#  6.71,
#  8.01,
#  2.26,
#  2.37,
#  4.7,
#  5.82,
#  1.12,
#  6.73,
#  19.46,
#  11.41,
#  8.08,
#  1.99,
#  2.93,
#  2.24,
#  4.7,
#  4.83,
#  13.87,
#  17.36,
#  8.19,
#  2.71,
#  25.52,
#  17.47,
#  4.5,
#  6.93,
#  9.17,
#  8.05,
#  2.71,
#  10.29,
#  3.71,
#  0.36,
#  20.8,
#  2.93,
#  6.93,
#  5.82,
#  3.94,
#  5.28,
#  1.12,
#  9.17,
#  2.93,
#  10.65,
#  5.82,
#  11.01,
#  6.93,
#  13.87,
#  12.75,
#  1.12,
#  6.71,
#  3.71,
#  3.38,
#  19.46,
#  1.36,
#  16.11,
#  4.16,
#  6.93,
#  2.71,
#  3.15,
#  8.3,
#  2.26,
#  11.77,
#  5.95,
#  13,
#  8.05,
#  3.36,
#  3.04,
#  14.99,
#  6.4,
#  2.59,
#  9.64,
#  2.15,
#  3.36,
#  9.17,
#  3.15,
#  5.73,
#  4.05,
#  6.4,
#  3.94,
#  13.87,
#  4,
#  3.49,
#  3.04,
#  10.2,
#  9.64,
#  6.93,
#  10.29,
#  29.1,
#  12.21,
#  3.36]

# %%
print(len(cloudiness))
# Out:
# 336

# %%
cloudiness
# Out:
# [92,
#  88,
#  8,
#  75,
#  5,
#  92,
#  100,
#  75,
#  90,
#  68,
#  0,
#  36,
#  64,
#  20,
#  90,
#  75,
#  0,
#  64,
#  75,
#  5,
#  0,
#  36,
#  0,
#  64,
#  75,
#  0,
#  0,
#  90,
#  8,
#  0,
#  0,
#  36,
#  0,
#  12,
#  76,
#  76,
#  76,
#  0,
#  92,
#  0,
#  20,
#  0,
#  80,
#  75,
#  0,
#  40,
#  1,
#  75,
#  20,
#  8,
#  56,
#  0,
#  75,
#  90,
#  40,
#  1,
#  0,
#  68,
#  40,
#  32,
#  40,
#  76,
#  40,
#  0,
#  48,
#  12,
#  90,
#  90,
#  64,
#  40,
#  8,
#  8,
#  36,
#  90,
#  0,
#  90,
#  64,
#  1,
#  76,
#  92,
#  76,
#  40,
#  0,
#  0,
#  0,
#  75,
#  90,
#  75,
#  0,
#  20,
#  76,
#  48,
#  80,
#  5,
#  1,
#  56,
#  0,
#  90,
#  0,
#  76,
#  12,
#  40,
#  36,
#  0,
#  36,
#  76,
#  88,
#  0,
#  75,
#  75,
#  90,
#  90,
#  40,
#  0,
#  75,
#  20,
#  76,
#  40,
#  90,
#  76,
#  90,
#  80,
#  80,
#  12,
#  5,
#  0,
#  32,
#  0,
#  20,
#  76,
#  56,
#  0,
#  8,
#  40,
#  0,
#  80,
#  24,
#  75,
#  20,
#  36,
#  76,
#  40,
#  0,
#  24,
#  1,
#  80,
#  0,
#  0,
#  0,
#  0,
#  20,
#  12,
#  0,
#  68,
#  90,
#  90,
#  0,
#  92,
#  32,
#  56,
#  20,
#  80,
#  8,
#  88,
#  0,
#  48,
#  40,
#  0,
#  12,
#  92,
#  0,
#  80,
#  1,
#  32,
#  5,
#  0,
#  0,
#  88,
#  75,
#  24,
#  40,
#  75,
#  88,
#  20,
#  90,
#  48,
#  12,
#  1,
#  40,
#  0,
#  20,
#  40,
#  92,
#  90,
#  0,
#  64,
#  0,
#  0,
#  0,
#  0,
#  1,
#  90,
#  20,
#  56,
#  75,
#  90,
#  12,
#  36,
#  56,
#  88,
#  75,
#  36,
#  0,
#  75,
#  0,
#  75,
#  90,
#  75,
#  75,
#  64,
#  75,
#  0,
#  40,
#  92,
#  20,
#  92,
#  68,
#  76,
#  88,
#  24,
#  0,
#  20,
#  1,
#  0,
#  36,
#  90,
#  5,
#  75,
#  76,
#  20,
#  0,
#  8,
#  20,
#  12,
#  0,
#  0,
#  56,
#  90,
#  92,
#  90,
#  56,
#  1,
#  0,
#  75,
#  40,
#  75,
#  88,
#  40,
#  40,
#  5,
#  64,
#  90,
#  90,
#  90,
#  76,
#  75,
#  0,
#  0,
#  0,
#  8,
#  0,
#  0,
#  0,
#  20,
#  75,
#  24,
#  75,
#  0,
#  92,
#  0,
#  44,
#  0,
#  75,
#  64,
#  90,
#  75,
#  0,
#  0,
#  12,
#  20,
#  0,
#  75,
#  0,
#  75,
#  0,
#  0,
#  12,
#  68,
#  5,
#  20,
#  75,
#  56,
#  0,
#  88,
#  20,
#  0,
#  20,
#  0,
#  88,
#  0,
#  0,
#  5,
#  88,
#  20,
#  0,
#  1,
#  12,
#  64,
#  20,
#  5,
#  88,
#  75,
#  12,
#  24,
#  48,
#  40,
#  0,
#  24,
#  80,
#  44,
#  64,
#  0,
#  90,
#  92,
#  24,
#  0]

# %%
print(len(date))
# Out:
# 336

# %%
date
# Out:
# [1551496762,
#  1551497491,
#  1551497492,
#  1551492000,
#  1551495600,
#  1551496800,
#  1551497390,
#  1551495600,
#  1551496620,
#  1551497499,
#  1551497500,
#  1551497009,
#  1551497448,
#  1551497311,
#  1551497318,
#  1551495600,
#  1551497318,
#  1551497505,
#  1551496386,
#  1551495600,
#  1551495535,
#  1551497358,
#  1551495600,
#  1551497512,
#  1551497339,
#  1551497513,
#  1551496804,
#  1551496702,
#  1551497008,
#  1551497520,
#  1551492000,
#  1551497523,
#  1551497524,
#  1551495600,
#  1551497336,
#  1551497008,
#  1551496802,
#  1551495000,
#  1551497532,
#  1551497533,
#  1551496703,
#  1551496834,
#  1551497357,
#  1551495600,
#  1551496899,
#  1551497440,
#  1551497308,
#  1551497464,
#  1551495600,
#  1551496591,
#  1551497543,
#  1551492000,
#  1551495600,
#  1551497525,
#  1551497471,
#  1551497546,
#  1551497343,
#  1551496799,
#  1551496652,
#  1551497551,
#  1551495600,
#  1551497553,
#  1551495000,
#  1551497007,
#  1551497143,
#  1551497346,
#  1551497559,
#  1551497313,
#  1551497562,
#  1551495600,
#  1551497563,
#  1551497564,
#  1551497565,
#  1551495600,
#  1551495600,
#  1551497512,
#  1551497517,
#  1551497507,
#  1551497574,
#  1551495000,
#  1551497576,
#  1551496776,
#  1551497580,
#  1551497581,
#  1551497582,
#  1551495600,
#  1551497522,
#  1551497524,
#  1551497588,
#  1551497353,
#  1551497590,
#  1551497590,
#  1551497209,
#  1551497482,
#  1551496800,
#  1551497348,
#  1551496763,
#  1551495600,
#  1551497596,
#  1551495600,
#  1551497599,
#  1551495000,
#  1551497601,
#  1551497335,
#  1551497603,
#  1551497604,
#  1551495600,
#  1551497608,
#  1551497519,
#  1551497586,
#  1551497605,
#  1551495600,
#  1551495600,
#  1551497613,
#  1551497548,
#  1551495600,
#  1551495600,
#  1551495600,
#  1551496740,
#  1551496889,
#  1551497612,
#  1551495600,
#  1551497624,
#  1551497624,
#  1551497565,
#  1551497612,
#  1551497630,
#  1551497630,
#  1551497471,
#  1551497632,
#  1551497633,
#  1551497633,
#  1551497634,
#  1551497455,
#  1551497407,
#  1551497639,
#  1551497640,
#  1551497412,
#  1551497564,
#  1551497642,
#  1551497644,
#  1551495600,
#  1551497463,
#  1551497650,
#  1551495600,
#  1551497651,
#  1551497505,
#  1551497653,
#  1551497487,
#  1551497647,
#  1551497659,
#  1551497659,
#  1551497660,
#  1551497661,
#  1551497616,
#  1551497599,
#  1551497664,
#  1551497589,
#  1551495000,
#  1551497668,
#  1551497625,
#  1551497670,
#  1551497358,
#  1551497672,
#  1551497404,
#  1551497673,
#  1551497612,
#  1551495600,
#  1551497583,
#  1551497679,
#  1551497680,
#  1551497681,
#  1551497607,
#  1551497682,
#  1551495600,
#  1551497584,
#  1551495600,
#  1551497687,
#  1551497056,
#  1551497689,
#  1551497654,
#  1551495600,
#  1551497691,
#  1551495600,
#  1551497424,
#  1551496801,
#  1551497580,
#  1551497540,
#  1551495600,
#  1551497585,
#  1551497622,
#  1551497401,
#  1551497690,
#  1551497619,
#  1551495600,
#  1551497709,
#  1551497707,
#  1551497710,
#  1551497711,
#  1551497712,
#  1551497553,
#  1551497589,
#  1551495600,
#  1551497717,
#  1551495600,
#  1551497711,
#  1551497719,
#  1551497436,
#  1551497720,
#  1551497721,
#  1551497511,
#  1551497707,
#  1551497724,
#  1551497717,
#  1551497658,
#  1551497160,
#  1551497719,
#  1551497640,
#  1551495600,
#  1551497732,
#  1551495600,
#  1551497736,
#  1551495600,
#  1551497738,
#  1551497629,
#  1551497739,
#  1551497740,
#  1551497740,
#  1551497741,
#  1551497742,
#  1551497742,
#  1551496401,
#  1551497493,
#  1551497528,
#  1551497749,
#  1551497742,
#  1551495600,
#  1551497464,
#  1551497754,
#  1551497739,
#  1551497262,
#  1551495000,
#  1551496200,
#  1551497243,
#  1551497460,
#  1551497682,
#  1551497765,
#  1551497715,
#  1551497768,
#  1551495600,
#  1551497656,
#  1551497770,
#  1551497772,
#  1551495600,
#  1551497727,
#  1551497748,
#  1551497778,
#  1551497517,
#  1551495600,
#  1551497540,
#  1551497585,
#  1551497745,
#  1551495600,
#  1551495600,
#  1551497790,
#  1551497554,
#  1551497541,
#  1551497792,
#  1551497794,
#  1551497796,
#  1551497797,
#  1551497797,
#  1551497793,
#  1551495600,
#  1551495000,
#  1551497806,
#  1551497640,
#  1551497541,
#  1551497808,
#  1551495600,
#  1551497809,
#  1551495600,
#  1551497804,
#  1551497811,
#  1551497794,
#  1551497788,
#  1551495000,
#  1551497818,
#  1551497819,
#  1551495600,
#  1551497585,
#  1551497421,
#  1551495600,
#  1551497545,
#  1551497811,
#  1551495600,
#  1551497837,
#  1551497837,
#  1551495600,
#  1551495600,
#  1551497599,
#  1551497842,
#  1551497792,
#  1551497848,
#  1551497849,
#  1551497850,
#  1551497851,
#  1551497852,
#  1551497854,
#  1551497497,
#  1551495600,
#  1551497483,
#  1551497858,
#  1551496940,
#  1551497859,
#  1551497754,
#  1551497862,
#  1551497865,
#  1551495600,
#  1551494640,
#  1551497869,
#  1551495600,
#  1551497884,
#  1551497885,
#  1551497888,
#  1551497831,
#  1551497543,
#  1551497890,
#  1551497756,
#  1551497895,
#  1551497896,
#  1551495600,
#  1551497711,
#  1551497899,
#  1551497900,
#  1551497488]

# %%
print(len(country))
# Out:
# 336

# %%
country
# Out:
# ['PF',
#  'RU',
#  'BR',
#  'AR',
#  'CA',
#  'FO',
#  'BR',
#  'AE',
#  'US',
#  'MV',
#  'MX',
#  'AU',
#  'ZA',
#  'CA',
#  'CA',
#  'BN',
#  'JP',
#  'ID',
#  'CL',
#  'CA',
#  'AU',
#  'GL',
#  'CL',
#  'TL',
#  'MU',
#  'IR',
#  'NZ',
#  'US',
#  'EC',
#  'ML',
#  'SD',
#  'NO',
#  'RU',
#  'BO',
#  'KI',
#  'PT',
#  'BR',
#  'OM',
#  'BR',
#  'NZ',
#  'US',
#  'RU',
#  'RU',
#  'AR',
#  'AU',
#  'UY',
#  'CA',
#  'EC',
#  'ET',
#  'ZA',
#  'EE',
#  'IN',
#  'ZA',
#  'US',
#  'US',
#  'US',
#  'GL',
#  'RU',
#  'ZA',
#  'ID',
#  'BR',
#  'RU',
#  'TR',
#  'PF',
#  'AU',
#  'RU',
#  'US',
#  'US',
#  'RU',
#  'ID',
#  'BF',
#  'RU',
#  'PG',
#  'BR',
#  'AR',
#  'PT',
#  'ZA',
#  'US',
#  'MZ',
#  'GL',
#  'RU',
#  'JP',
#  'BR',
#  'ZA',
#  'PH',
#  'CL',
#  'US',
#  'FR',
#  'IN',
#  'AR',
#  'RU',
#  'RU',
#  'SE',
#  'MX',
#  'KR',
#  'ZA',
#  'AR',
#  'TM',
#  'NA',
#  'CK',
#  'ID',
#  'NO',
#  'RU',
#  'AU',
#  'PG',
#  'NO',
#  'GF',
#  'ML',
#  'CA',
#  'US',
#  'FR',
#  'CA',
#  'IN',
#  'MX',
#  'BR',
#  'CO',
#  'NU',
#  'VN',
#  'JP',
#  'RU',
#  'FR',
#  'AU',
#  'RU',
#  'GL',
#  'CA',
#  'GR',
#  'NE',
#  'MX',
#  'PA',
#  'CD',
#  'BR',
#  'LY',
#  'BR',
#  'US',
#  'NZ',
#  'ZM',
#  'AU',
#  'AU',
#  'CA',
#  'PH',
#  'RU',
#  'GY',
#  'AR',
#  'RU',
#  'CA',
#  'ID',
#  'FR',
#  'NA',
#  'RU',
#  'NO',
#  'IN',
#  'PH',
#  'PH',
#  'RU',
#  'US',
#  'BE',
#  'ET',
#  'FR',
#  'GL',
#  'RU',
#  'JP',
#  'AO',
#  'CA',
#  'RU',
#  'NZ',
#  'RU',
#  'GR',
#  'EG',
#  'AR',
#  'AF',
#  'CD',
#  'MG',
#  'CA',
#  'ZA',
#  'CA',
#  'AU',
#  'AR',
#  'CN',
#  'IS',
#  'ID',
#  'PT',
#  'NC',
#  'NP',
#  'BB',
#  'US',
#  'PG',
#  'CO',
#  'CA',
#  'IN',
#  'NZ',
#  'JP',
#  'PA',
#  'PF',
#  'US',
#  'AU',
#  'AU',
#  'AR',
#  'MN',
#  'CN',
#  'RU',
#  'US',
#  'FR',
#  'JP',
#  'ID',
#  'MG',
#  'US',
#  'ID',
#  'BR',
#  'RU',
#  'BR',
#  'AU',
#  'TT',
#  'CN',
#  'NO',
#  'MX',
#  'AU',
#  'US',
#  'MU',
#  'CA',
#  'KZ',
#  'CN',
#  'UY',
#  'AU',
#  'SB',
#  'US',
#  'SO',
#  'BR',
#  'RU',
#  'NG',
#  'NP',
#  'UA',
#  'CA',
#  'CA',
#  'PT',
#  'BR',
#  'US',
#  'CA',
#  'EC',
#  'CD',
#  'US',
#  'CN',
#  'NO',
#  'LK',
#  'CA',
#  'FR',
#  'IT',
#  'CA',
#  'US',
#  'AO',
#  'CN',
#  'CA',
#  'US',
#  'PY',
#  'CL',
#  'JP',
#  'IT',
#  'NG',
#  'JP',
#  'PH',
#  'MX',
#  'IE',
#  'US',
#  'BR',
#  'GE',
#  'BR',
#  'AU',
#  'VN',
#  'RU',
#  'UG',
#  'CA',
#  'CV',
#  'RU',
#  'ES',
#  'BR',
#  'PW',
#  'GH',
#  'MU',
#  'TR',
#  'EC',
#  'CV',
#  'RU',
#  'JP',
#  'DE',
#  'RU',
#  'US',
#  'ES',
#  'NO',
#  'YE',
#  'UY',
#  'JM',
#  'NZ',
#  'MX',
#  'AU',
#  'AU',
#  'PL',
#  'RU',
#  'RU',
#  'IN',
#  'CA',
#  'BO',
#  'AU',
#  'AO',
#  'SE',
#  'CO',
#  'BR',
#  'AR',
#  'BR',
#  'PH',
#  'DZ',
#  'AR',
#  'MR',
#  'MX',
#  'BR',
#  'JP',
#  'RU',
#  'US',
#  'RU',
#  'RU',
#  'EG',
#  'MX',
#  'NG',
#  'ID',
#  'IN',
#  'CA',
#  'TZ',
#  'AU',
#  'US',
#  'RU',
#  'SO',
#  'TZ',
#  'PA',
#  'PY',
#  'US',
#  'IS',
#  'PH',
#  'ES']

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
CityData_Weather = pd.DataFrame({
    "City": city_list, 
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lon,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
})
                        
CityData_Weather.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Rikitea          92      PF  1551496762       100 -23.12 -134.97
# 1         Foki          88      RU  1551497491        93  56.69   54.35
# 2      Vilhena           8      BR  1551497492        95 -12.74  -60.15
# 3      Ushuaia          75      AR  1551492000        76 -54.81  -68.31
# 4  Tuktoyaktuk           5      CA  1551495600        64  69.44 -133.03
#
#    Max Temp  Wind Speed
# 0     78.31       13.00
# 1     28.68        5.73
# 2     70.84        2.15
# 3     50.00        2.82
# 4     -4.01       16.11

# %%
# Save as a csv
CityData_Weather.to_csv(output_data_file, encoding="utf-8", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Build scatter plot for Temperature vs. Latitude

plt.scatter (lat, max_temp, facecolors="lightcoral", edgecolors="black", alpha=0.7, linewidth=1, marker="o")

# Incorporate title and labels into the scatter plots 

plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.grid()
plt.savefig("images/MaxTemp.png")
plt.tight_layout()
plt.show()

# %%
# Build scatter plot for Humidity vs. Latitude

plt.scatter (lat, humidity, facecolors="lightskyblue", edgecolors="black", alpha=0.7, linewidth=1, marker="o")

# Incorporate title and labels into the scatter plots 

plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.grid()
plt.savefig("images/Humidity.png")
plt.tight_layout()
plt.show()

# %%
# Build scatter plot for Cloudiness vs. Latitude

plt.scatter (lat, cloudiness, facecolors="gold", edgecolors="black", alpha=0.7, linewidth=1, marker="o")

# Incorporate title and labels into the scatter plots 

plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.grid()
plt.savefig("images/Cloudiness.png")
plt.tight_layout()
plt.show()

# %%
# Build scatter plot for Wind Speed vs. Latitude

plt.scatter (lat, wind_speed, facecolors="black", edgecolors="black", alpha=0.7, linewidth=1, marker="o")

# Incorporate title and labels into the scatter plots 

plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.grid()
plt.savefig("images/Wind.png")
plt.tight_layout()
plt.show()

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
